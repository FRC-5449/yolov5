# %%
import numpy as np
pictureDepth = np.load("test.npz", allow_pickle=True)

# %%
depth = pictureDepth["depth"]
det = pictureDepth["det"]

# %%
for item in det:
    x1,y1,x2,y2 = item[0]
    iclass = item[1]
    area =

    print()
    # break
# Out:
# [138.01695 -26.23825 257.57465]
#
# [623.12274  -29.335222  90.45972 ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

area = depth
area[area==np.Inf] = np.max(area[area!=np.Inf])
area[area==-np.Inf] = np.min(area[area!=-np.Inf])
area = np.ma.clip(area,0,255)
plt.imshow(area, cmap="gray")
plt.show()

# %%
copyright()
# Out:
# Copyright (c) 2001-2020 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.
